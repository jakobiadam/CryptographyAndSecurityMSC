# %%
#Does exactly as pow() built in function........
def powMod(x, n, m):
    """Function to effectively calculate (x ** n) % m (power modulo function)."""
    x = x % m
    if (n < 1):
        return x

    res = 1

    while (n > 1):
        if (n % 2):
            res = (res * x) % m
            n -= 1
        x = (x * x) % m
        n = n // 2

    return (res * x) % m

def gcd(a, b):
    while (b != 0):
        a, b = b, a % b
    return a

def sieve(primeMax):
    primes = np.ones(primeMax+1, dtype = int)
    primes[0] = 0
    primes[1] = 0
    stop = int(math.sqrt(primeMax))
    i = 2
    while (i <= stop):
        if primes[i]:
            primes[i*i::i] = 0
        i += 1
    return primes

a = "0x17af43c3"
b = "0x32510a45"

def xor(x,y):
    return hex(int(x,16) ^ int(y,16))

xor(a, xor(a,b))

def isPrime(n):
    
    if n <= 3:
        return n > 1
    
    if (not n % 2) or (not n % 3):
        return False
    
    div = 5
    stop = int(n ** 0.5)
    while div <= stop:
        if (not n % div) or (not n % (div + 2)):
            return False
        div += 6

    return True
